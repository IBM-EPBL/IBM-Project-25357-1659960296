# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# # Loading The Dataset

# %%
df=pd.read_csv('loan_prediction.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# # Replace str dependents column into float column

# %%
df['Dependents']=df['Dependents'].str.replace('+',' ').astype('float')
# Out:
# C:\Users\Dhamu\AppData\Local\Temp\ipykernel_10820\2408825922.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Dependents']=df['Dependents'].str.replace('+',' ').astype('float')

# %%
df['Dependents']
# Out:
# 0      0.0
# 1      1.0
# 2      0.0
# 3      0.0
# 4      0.0
#       ...
# 609    0.0
# 610    3.0
# 611    1.0
# 612    2.0
# 613    0.0
# Name: Dependents, Length: 614, dtype: float64

# %% [markdown]
# # Univariate Analysis on Dataset

# %%
sns.distplot(df['Dependents'])
# Out:
# C:\Users\Dhamu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Dependents', ylabel='Density'>

# %%
sns.distplot(df['Dependents'])
# Out:
# C:\Users\Dhamu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Dependents', ylabel='Density'>

# %%
sns.distplot(df['ApplicantIncome'])
# Out:
# C:\Users\Dhamu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='Density'>

# %%
sns.distplot(df['CoapplicantIncome'])
# Out:
# C:\Users\Dhamu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CoapplicantIncome', ylabel='Density'>

# %% [markdown]
# # Bivariate Analysis On Dataset

# %%
sns.countplot(df['Loan_Amount_Term'],hue=df['Property_Area'])
# Out:
# C:\Users\Dhamu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Loan_Amount_Term', ylabel='count'>

# %%
sns.countplot(df['Education'],hue=df['Loan_Status'])
# Out:
# C:\Users\Dhamu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# # Multivariate Analysis on Dataset

# %%
sns.pairplot(df)

# %%
sns.swarmplot(df['Education'],df['Property_Area'],df['Loan_Status'])
# Out:
# C:\Users\Dhamu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Dhamu\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 83.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Dhamu\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 39.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Education', ylabel='Property_Area'>

# %% [markdown]
# # Descriptive Analysis On Dataset

# %%
df.describe()
# Out:
#        Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  599.000000       614.000000         614.000000  592.000000
# mean     0.762938      5403.459283        1621.245798  146.412162
# std      1.015216      6109.041673        2926.248369   85.587325
# min      0.000000       150.000000           0.000000    9.000000
# 25%      0.000000      2877.500000           0.000000  100.000000
# 50%      0.000000      3812.500000        1188.500000  128.000000
# 75%      2.000000      5795.000000        2297.250000  168.000000
# max      3.000000     81000.000000       41667.000000  700.000000
#
#        Loan_Amount_Term  Credit_History
# count         600.00000      564.000000
# mean          342.00000        0.842199
# std            65.12041        0.364878
# min            12.00000        0.000000
# 25%           360.00000        1.000000
# 50%           360.00000        1.000000
# 75%           360.00000        1.000000
# max           480.00000        1.000000
